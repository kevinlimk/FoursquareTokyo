# %% [markdown]
# # Predicting Check-ins of Foursquare Users in Tokyo

# %% [markdown]
# ## 4 - Machine Learning

# %%
# Import libraries
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
from matplotlib import rcParams

from sklearn.preprocessing import normalize
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score

from sklearn.metrics import confusion_matrix

import itertools

# %matplotlib inline

# %%
# Setup default matplotlib defaults for later use
def defaultsettings():
    rcParams.update(matplotlib.rcParamsDefault)
    sns.set_style()
    sns.set_context()
    # %matplotlib inline

# %%
# Setup Seaborn settings for bar plots
def postersettings():
    rcParams.update(matplotlib.rcParamsDefault)
    sns.set_style("whitegrid")
    sns.set_context("poster")

# %%
df_X0 = pd.read_csv('df_X0.csv',
                    index_col = 0,
                    parse_dates = [0],
                    date_parser = pd.to_datetime,
                    infer_datetime_format = True)

# %%
df_X0.head()
# Out:
#                      rollavg_0  rollavg_1  rollavg_2  weekday_morning  \
# timestamp
# 2012-04-04 03:17:18        0.0        0.0        1.0             True
# 2012-04-04 03:22:04        0.0        0.0        1.0             True
# 2012-04-04 04:12:07        0.0        0.0        1.0             True
# 2012-04-04 04:12:13        0.0        0.0        1.0             True
# 2012-04-04 04:18:23        0.0        0.0        1.0             True
#
#                      weekday_afternoon  weekday_evening  weekend_morning  \
# timestamp
# 2012-04-04 03:17:18              False            False            False
# 2012-04-04 03:22:04              False            False            False
# 2012-04-04 04:12:07              False            False            False
# 2012-04-04 04:12:13              False            False            False
# 2012-04-04 04:18:23              False            False            False
#
#                      weekend_afternoon  weekend_evening  train_nearby  \
# timestamp
# 2012-04-04 03:17:18              False            False          True
# 2012-04-04 03:22:04              False            False         False
# 2012-04-04 04:12:07              False            False         False
# 2012-04-04 04:12:13              False            False         False
# 2012-04-04 04:18:23              False            False         False
#
#                         ...        y1  rollavg_0.1  rollavg_1.1  rollavg_2.1  \
# timestamp               ...
# 2012-04-04 03:17:18     ...       129          0.0          0.0          1.0
# 2012-04-04 03:22:04     ...         2          0.0          0.0          1.0
# 2012-04-04 04:12:07     ...         3          0.0          0.0          1.0
# 2012-04-04 04:12:13     ...         6          0.0          0.0          1.0
# 2012-04-04 04:18:23     ...       212          0.0          0.0          1.0
#
#                      rollavg_0.2  rollavg_1.2  rollavg_2.2  rollavg_0.3  \
# timestamp
# 2012-04-04 03:17:18          0.0          0.0          1.0          0.0
# 2012-04-04 03:22:04          0.0          0.0          1.0          0.0
# 2012-04-04 04:12:07          0.0          0.0          1.0          0.0
# 2012-04-04 04:12:13          0.0          0.0          1.0          0.0
# 2012-04-04 04:18:23          0.0          0.0          1.0          0.0
#
#                      rollavg_1.3  rollavg_2.3
# timestamp
# 2012-04-04 03:17:18          0.0          1.0
# 2012-04-04 03:22:04          0.0          1.0
# 2012-04-04 04:12:07          0.0          1.0
# 2012-04-04 04:12:13          0.0          1.0
# 2012-04-04 04:18:23          0.0          1.0
#
# [5 rows x 22 columns]

# %%
df_X0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 573703 entries, 2012-04-04 03:17:18 to 2013-02-16 11:35:29
# Data columns (total 22 columns):
# rollavg_0            573703 non-null float64
# rollavg_1            573703 non-null float64
# rollavg_2            573703 non-null float64
# weekday_morning      573703 non-null bool
# weekday_afternoon    573703 non-null bool
# weekday_evening      573703 non-null bool
# weekend_morning      573703 non-null bool
# weekend_afternoon    573703 non-null bool
# weekend_evening      573703 non-null bool
# train_nearby         573703 non-null bool
# subway_nearby        573703 non-null bool
# y0                   573703 non-null int64
# y1                   573703 non-null int64
# rollavg_0.1          573703 non-null float64
# rollavg_1.1          573703 non-null float64
# rollavg_2.1          573703 non-null float64
# rollavg_0.2          573703 non-null float64
# rollavg_1.2          573703 non-null float64
# rollavg_2.2          573703 non-null float64
# rollavg_0.3          573703 non-null float64
# rollavg_1.3          573703 non-null float64
# rollavg_2.3          573703 non-null float64
# dtypes: bool(8), float64(12), int64(2)
# memory usage: 70.0 MB

# %%
# Run Logistic Regression

Xtrain0 = df_X0['2012-July':'2013-Jan'].drop(['y0', 'y1'], axis = 1)
Xtest0 = df_X0['2013-Feb':].drop(['y0', 'y1'], axis = 1)
ytrain0 = df_X0['2012-July':'2013-Jan']
ytest0 = df_X0['2013-Feb':]

clf_LR0 = LogisticRegression()
clf_LR0.fit(Xtrain0, ytrain0.y0)
ypred0 = clf_LR0.predict(Xtest0)
print("Accuracy: " + str(round(accuracy_score(ytest0.y0, ypred0) * 100, 2)) + "%")
# Out:
# Accuracy: 83.01%
